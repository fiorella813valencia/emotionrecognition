# %%
import cv2
import tensorflow as tf 
print('imported')
# Out:
# imported

# %%
from deepface import DeepFace
print ('te amo adolfo cucho')
# Out:
# te amo adolfo cucho

# %%
img=cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 24-01-26 21:28:43 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\fiore\.deepface\weights\facial_expression_model_weights.h5
#
#   0%|                                                                                      | 0.00/5.98M [00:00<?, ?B/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 5.98M/5.98M [00:00<00:00, 11.8MB/s]
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:03<00:10,  3.36s/it]
# 24-01-26 21:28:48 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# ...

# %%
predictions
# Out:
# [{'emotion': {'angry': 1.4570716696757398e-17,
#    'disgust': 1.9942667952390427e-22,
#    'fear': 1.6295250279524772e-14,
#    'happy': 100.0,
#    'sad': 4.488188300692938e-14,
#    'surprise': 1.3674006239083853e-14,
#    'neutral': 4.2430290392303505e-07},
#   'dominant_emotion': 'happy',
#   'region': {'x': 154, 'y': 141, 'w': 302, 'h': 302},
#   'face_confidence': 9.779761986748781,
#   'age': 23,
#   'gender': {'Woman': 0.09047634666785598, 'Man': 99.90952014923096},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.030231522396206856,
#    'indian': 0.1302565447986126,
#    'black': 0.003632818697951734,
#    'white': 79.87198829650879,
#    'middle eastern': 10.665666311979294,
#    'latino hispanic': 9.298227727413177},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces :
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
valor_dominante = predictions[0]['dominant_emotion']
print(valor_dominante)
# Out:
# happy

# %%
font =cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
           valor_dominante,
           (0,50),
           font,2,
           (0,0,255),
           2,
           cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img=cv2.imread('sadwomen.jpg')

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.02it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.01706924041959586,
#    'disgust': 0.0038421740571727412,
#    'fear': 73.92648899117046,
#    'happy': 1.0253049021420743e-10,
#    'sad': 26.046423676396827,
#    'surprise': 0.004149573825949547,
#    'neutral': 0.002035401242566928},
#   'dominant_emotion': 'fear',
#   'region': {'x': 512, 'y': 314, 'w': 401, 'h': 401},
#   'face_confidence': 11.141736009565648,
#   'age': 29,
#   'gender': {'Woman': 99.99938011169434, 'Man': 0.0006145035513327457},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 4.14212445271757,
#    'indian': 10.369101784771788,
#    'black': 0.5356259031966867,
#    'white': 17.0482571153794,
#    'middle eastern': 48.789769338951665,
#    'latino hispanic': 19.115119821734417},
#   'dominant_race': 'middle eastern'}]

# %%
valor_dominante = predictions[0]['dominant_emotion']
print(valor_dominante)
# Out:
# fear

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces :
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
font =cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
           valor_dominante,
           (0,50),
           font,2,
           (0,0,255),
           2,
           cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
import cv2
from deepface import DeepFace

faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap=cv2.VideoCapture(0)

if not cap.isOpened():
    cap=cv2.VideoCapture(0)
    
if not cap.isOpened():
    raise IOError('cannot open webcam')

while True:
    ret,frame=cap.read()
    result=DeepFace.analyze(frame,actions=['emotion'])
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces=faceCascade.detectMultiScale(gray,1.1,4)
    for(x,y,w,h) in faces :
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
        
    font =cv2.FONT_HERSHEY_SIMPLEX
    if result:
        valor_dominante = result[0]['dominant_emotion']
    else:
        valor_dominante = "No face detected"
    cv2.putText(frame,
           valor_dominante,
           (0,50),
           font,2,
           (0,0,255),
           2,
           cv2.LINE_4) 
    cv2.imshow('Original video',frame)
    if cv2.waitKey(2) & 0xFF==ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 16
#      14 while True:
#      15     ret,frame=cap.read()
# ---> 16     result=DeepFace.analyze(frame,actions=['emotion'])
#      17     gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#      18     faces=faceCascade.detectMultiScale(gray,1.1,4)
#
# File ~\anaconda3\envs\radiohead\lib\site-packages\deepface\DeepFace.py:206, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     126 def analyze(
#     127     img_path: Union[str, np.ndarray],
#     128     actions: Union[tuple, list] = ("emotion", "age", "gender", "race"),
#    (...)
#     132     silent: bool = False,
#     133 ) -> List[Dict[str, Any]]:
#     134     """
#     135     Analyze facial attributes such as age, gender, emotion, and race in the provided image.
#     136     Args:
#    (...)
# ...
